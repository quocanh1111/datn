# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("StackCheck") \
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
    .getOrCreate()

print("Spark version:", spark.version)

# Quick Iceberg + Nessie test
spark.sql("CREATE NAMESPACE IF NOT EXISTS nessie.demo")
spark.sql("USE nessie.demo")
spark.sql("CREATE OR REPLACE TABLE ice_test (id bigint) USING iceberg")
spark.sql("INSERT INTO ice_test VALUES (42), (2026)")
spark.sql("SELECT * FROM ice_test").show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("StackCheck") \
#       5     .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
#       6     .getOrCreate()
#       8 print("Spark version:", spark.version)
#
# ModuleNotFoundError: No module named 'pyspark'
