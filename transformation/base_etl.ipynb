# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 40
#      38         print(f"Done — {len(data)} records landed")
#      39         return data
# ---> 40 baseetl = BaseETL()
#      41 baseelt.extract()
#
# TypeError: Can't instantiate abstract class BaseETL with abstract methods extract
